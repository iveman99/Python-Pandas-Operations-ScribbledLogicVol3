# %%
#iVeman : Pandas Operations

# %%
import pandas as pd
import numpy as np

# %%
p_id = [2000,2001,2002,2003,2004]
p_name = ['Veman','Pranav','Mayur','Kunal','Shashi']
p_role = ['DS','SW','GD','RE','TS']

# %%
d1 ={"Id" : p_id,"Name" : p_name,"Role" : p_role}

# %%
Person = pd.DataFrame(d1)

# %%
Person
# Out:
#      Id    Name Role
# 0  2000   Veman   DS
# 1  2001  Pranav   SW
# 2  2002   Mayur   GD
# 3  2003   Kunal   RE
# 4  2004  Shashi   TS

# %%
Person["Age"]=[20,21,25,23,27] # adding one more columns

# %%
Person
# Out:
#      Id    Name Role  Age
# 0  2000   Veman   DS   20
# 1  2001  Pranav   SW   21
# 2  2002   Mayur   GD   25
# 3  2003   Kunal   RE   23
# 4  2004  Shashi   TS   27

# %%
Person.shape
# Out:
# (5, 4)

# %%
#renameing columns

# %%
Person.rename(columns={"Id" : "Roll_no"},inplace= True)

# %%
Person
# Out:
#    Roll_no    Name Role  Age
# 0     2000   Veman   DS   20
# 1     2001  Pranav   SW   21
# 2     2002   Mayur   GD   25
# 3     2003   Kunal   RE   23
# 4     2004  Shashi   TS   27

# %%
p_uid = [1,2,3,4,5]
Roll_no = [2000,2001,2001,2000,2003]
p_units = [30,2,78,35,25]
p_name = ["Clothing","Foods","Wearables","Gifting","Acessories"]

# %%
d2 = {"uid":p_uid,"id":p_id,"units":p_units,"name":p_name}

# %%
d2
# Out:
# {'uid': [1, 2, 3, 4, 5],
#  'id': [2000, 2001, 2002, 2003, 2004],
#  'units': [30, 2, 78, 35, 25],
#  'name': ['Clothing', 'Foods', 'Wearables', 'Gifting', 'Acessories']}

# %%
D2 = pd.DataFrame(d2)

# %%
D2
# Out:
#    uid    id  units        name
# 0    1  2000     30    Clothing
# 1    2  2001      2       Foods
# 2    3  2002     78   Wearables
# 3    4  2003     35     Gifting
# 4    5  2004     25  Acessories

# %% [raw]
# D2.shape

# %%
D2.columns
# Out:
# Index(['uid', 'id', 'units', 'name'], dtype='object')

# %%
#print details of id number 100
[D2["id"]==2000]
# Out:
# [0     True
#  1    False
#  2    False
#  3    False
#  4    False
#  Name: id, dtype: bool]

# %%
D2[D2["id"]==2000]
# Out:
#    uid    id  units      name
# 0    1  2000     30  Clothing

# %%
#printing only name of the prodct

D2[D2["id"]==2003]["name"]
# Out:
# 3    Gifting
# Name: name, dtype: object

# %%
p_id = [100,101,102,103,104]
p_name = ['Shampoo','Deodrant','Toothpaste','Soap','Hairgel']
p_role = ['DS','SW','GD','RE','TS']
p_price = [50,30,50,70,40]

# %%
a1 = {"pid":p_id,"pname":p_name,"prole":p_role,"price":p_price}

# %%
Product = pd.DataFrame(a1)

# %%
Product
# Out:
#    pid       pname prole  price
# 0  100     Shampoo    DS     50
# 1  101    Deodrant    SW     30
# 2  102  Toothpaste    GD     50
# 3  103        Soap    RE     70
# 4  104     Hairgel    TS     40

# %%
p_uid = [1,2,3,4,5]
p_pid = [101,101,103,101,103]
p_units = [30,2,78,35,25]
p_name = ["Clothing","Foods","Wearables","Gifting","Acessories"]

# %%
a2={"id":p_uid,"pid":p_pid,"units":p_units,"name":p_name}

# %%
Order = pd.DataFrame(a2)

# %%
Order
# Out:
#    id  pid  units        name
# 0   1  101     30    Clothing
# 1   2  101      2       Foods
# 2   3  103     78   Wearables
# 3   4  101     35     Gifting
# 4   5  103     25  Acessories

# %%
#merging columns

#applying inner joing
pd.merge(Product, Order, how="inner", on="pid")
# Out:
#    pid     pname prole  price  id  units        name
# 0  101  Deodrant    SW     30   1     30    Clothing
# 1  101  Deodrant    SW     30   2      2       Foods
# 2  101  Deodrant    SW     30   4     35     Gifting
# 3  103      Soap    RE     70   3     78   Wearables
# 4  103      Soap    RE     70   5     25  Acessories

# %%
pd.merge(Product, Order, how="left", on="pid")
# Out:
#    pid       pname prole  price   id  units        name
# 0  100     Shampoo    DS     50  NaN    NaN         NaN
# 1  101    Deodrant    SW     30  1.0   30.0    Clothing
# 2  101    Deodrant    SW     30  2.0    2.0       Foods
# 3  101    Deodrant    SW     30  4.0   35.0     Gifting
# 4  102  Toothpaste    GD     50  NaN    NaN         NaN
# 5  103        Soap    RE     70  3.0   78.0   Wearables
# 6  103        Soap    RE     70  5.0   25.0  Acessories
# 7  104     Hairgel    TS     40  NaN    NaN         NaN

# %%
pd.merge(Product, Order, how="right", on="pid")
# Out:
#    pid     pname prole  price  id  units        name
# 0  101  Deodrant    SW     30   1     30    Clothing
# 1  101  Deodrant    SW     30   2      2       Foods
# 2  103      Soap    RE     70   3     78   Wearables
# 3  101  Deodrant    SW     30   4     35     Gifting
# 4  103      Soap    RE     70   5     25  Acessories

# %%
Order
# Out:
#    id  pid  units        name
# 0   1  101     30    Clothing
# 1   2  101      2       Foods
# 2   3  103     78   Wearables
# 3   4  101     35     Gifting
# 4   5  103     25  Acessories

# %%
#adding new row

new_row = {"id":6,"pid":102,"units":20,"name":"Gaming"}

# %%
new_df = pd.DataFrame(new_row,index = [5])

# %%
pd.concat([Order,new_df],axis = 0)
# Out:
#    id  pid  units        name
# 0   1  101     30    Clothing
# 1   2  101      2       Foods
# 2   3  103     78   Wearables
# 3   4  101     35     Gifting
# 4   5  103     25  Acessories
# 5   6  102     20      Gaming

# %%
#creating a another column df2 to merge pdf

# %%
df2=pd.merge(Product,Order,how = "right",on="pid")

# %%
df2["total_price"]=df2["price"]*df2["units"]

# %%
Order["total_price"] = df2["total_price"]

# %%
Order
# Out:
#    id  pid  units        name  total_price
# 0   1  101     30    Clothing          900
# 1   2  101      2       Foods           60
# 2   3  103     78   Wearables         5460
# 3   4  101     35     Gifting         1050
# 4   5  103     25  Acessories         1750

# %%
empcode = [101,102,103,104,105]
empcode
# Out:
# [101, 102, 103, 104, 105]

# %%
empcode = np.array([101,102,103,104,105])
empcode
# Out:
# array([101, 102, 103, 104, 105])

# %%
empname = np.array(["Veman","Sourabh","Harsh","Vivek","Aryan"])

# %%
empname
# Out:
# array(['Veman', 'Sourabh', 'Harsh', 'Vivek', 'Aryan'], dtype='<U7')

# %%
empcol = pd.Series(empname,empcode)

# %%
empcol
# Out:
# 101      Veman
# 102    Sourabh
# 103      Harsh
# 104      Vivek
# 105      Aryan
# dtype: object

# %%
empcol = pd.Series(empname,index=empcode)

# %%
empcol
# Out:
# 101      Veman
# 102    Sourabh
# 103      Harsh
# 104      Vivek
# 105      Aryan
# dtype: object

# %%
designation = pd.Series(["DS","AS","FD","WE","JH"],index = empcode)

# %%
designation
# Out:
# 101    DS
# 102    AS
# 103    FD
# 104    WE
# 105    JH
# dtype: object

# %%
age = pd.Series([20,24,23,21,26])

# %%
age
# Out:
# 0    20
# 1    24
# 2    23
# 3    21
# 4    26
# dtype: int64

# %%
age = pd.Series([20,24,23,21,26],index = empcode)
age
# Out:
# 101    20
# 102    24
# 103    23
# 104    21
# 105    26
# dtype: int64

# %%
d1 = {"Empname":empcol,"Designation":designation,"Age":age}
d1
# Out:
# {'Empname': 101      Veman
#  102    Sourabh
#  103      Harsh
#  104      Vivek
#  105      Aryan
#  dtype: object,
#  'Designation': 101    DS
#  102    AS
#  103    FD
#  104    WE
#  105    JH
#  dtype: object,
#  'Age': 101    20
#  102    24
#  103    23
#  104    21
#  105    26
#  dtype: int64}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#      Empname Designation  Age
# 101    Veman          DS   20
# 102  Sourabh          AS   24
# 103    Harsh          FD   23
# 104    Vivek          WE   21
# 105    Aryan          JH   26

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Empname', 'Designation', 'Age'], dtype='object')

# %%
df.head(2)
# Out:
#      Empname Designation  Age
# 101    Veman          DS   20
# 102  Sourabh          AS   24

# %%
df.tail()
# Out:
#      Empname Designation  Age
# 101    Veman          DS   20
# 102  Sourabh          AS   24
# 103    Harsh          FD   23
# 104    Vivek          WE   21
# 105    Aryan          JH   26

# %%
## exercise
first_name = ["Richie","Mark"]
nums = [800678,800456]

# %%
series_1 = pd.Series(nums)
series_1
# Out:
# 0    800678
# 1    800456
# dtype: int64

# %%
series_2 = pd.Series(nums,index = first_name)
series_2
# Out:
# Richie    800678
# Mark      800456
# dtype: int64

# %%
df
# Out:
#      Empname Designation  Age
# 101    Veman          DS   20
# 102  Sourabh          AS   24
# 103    Harsh          FD   23
# 104    Vivek          WE   21
# 105    Aryan          JH   26

# %%
df.T
# Out:
#                101      102    103    104    105
# Empname      Veman  Sourabh  Harsh  Vivek  Aryan
# Designation     DS       AS     FD     WE     JH
# Age             20       24     23     21     26

# %%
df.dtypes
# Out:
# Empname        object
# Designation    object
# Age             int64
# dtype: object

# %%
df.Empname
# Out:
# 101      Veman
# 102    Sourabh
# 103      Harsh
# 104      Vivek
# 105      Aryan
# Name: Empname, dtype: object

# %%
df["Empname"]
# Out:
# 101      Veman
# 102    Sourabh
# 103      Harsh
# 104      Vivek
# 105      Aryan
# Name: Empname, dtype: object

# %%
df[["Empname","Designation"]]
# Out:
#      Empname Designation
# 101    Veman          DS
# 102  Sourabh          AS
# 103    Harsh          FD
# 104    Vivek          WE
# 105    Aryan          JH

# %%
df.loc[[101,102]]
# Out:
#      Empname Designation  Age
# 101    Veman          DS   20
# 102  Sourabh          AS   24

# %%
df.loc[102:104,["Empname"]]
# Out:
#      Empname
# 102  Sourabh
# 103    Harsh
# 104    Vivek
